# %%
# !tar chvfz notebook.tar.gz *
# Out:
# Untitled.ipynb
# __pycache__/
# __pycache__/cnn_utils.cpython-36.pyc
# dummy/
# dummy/__pycache__/
# dummy/__pycache__/dataset.cpython-35.pyc
# dummy/__pycache__/cifar10.cpython-35.pyc
# dummy/__pycache__/input_data.cpython-36.pyc
# dummy/__pycache__/download.cpython-35.pyc
# dummy/__pycache__/cache.cpython-35.pyc
# dummy/__pycache__/cifar10.cpython-36.pyc
# dummy/__pycache__/dataset.cpython-36.pyc
# dummy/__pycache__/input_data.cpython-35.pyc
# dummy/__pycache__/download.cpython-36.pyc
# dummy/__pycache__/cache.cpython-36.pyc
# dummy/__pycache__/resnets_utils.cpython-36.pyc
# week1/
# week1/Convolution_model_Step_by_Step_v2a.ipynb
# week1/Convolution_model_Application_v1a.ipynb
# week1/.ipynb_checkpoints/
# week1/.ipynb_checkpoints/Convolution model - Step by Step - v1-checkpoint.ipynb
# week1/.ipynb_checkpoints/Convolution_model_Step_by_Step_v2a-checkpoint.ipynb
# week1/.ipynb_checkpoints/Convolution model - Application - v1-checkpoint.ipynb
# ...
